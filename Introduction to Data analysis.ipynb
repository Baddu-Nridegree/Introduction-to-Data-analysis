# %%
import random

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []

# %%
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
df = {
    'grade' : a1,
    'weight' : a2,
    'friends' : a3,
    'cousins' : a4,
    'projects' : a5,
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       50      69       12       10        71
# 1       87      50       19        5        32
# 2       98      60       13        7        80
# 3       11      61       16        5        38
# 4       84      57       14        6        65
# ..     ...     ...      ...      ...       ...
# 995     50      70       13       10        70
# 996     44      69       19        7        64
# 997     82      66       18        8        30
# 998      2      58       13        7        44
# 999     28      54       20       10        49
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends      cousins     projects
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     51.282000    60.284000    14.868000     7.515000    49.693000
# std      29.066774     5.949516     3.207938     1.684224    17.466191
# min       0.000000    50.000000    10.000000     5.000000    20.000000
# 25%      25.000000    55.000000    12.000000     6.000000    35.000000
# 50%      52.000000    60.000000    15.000000     8.000000    49.000000
# 75%      77.000000    66.000000    18.000000     9.000000    65.000000
# max     100.000000    70.000000    20.000000    10.000000    80.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0      50
# 1      87
# 2      98
# 3      11
# 4      84
#        ..
# 995    50
# 996    44
# 997    82
# 998     2
# 999    28
# Name: grade, Length: 1000, dtype: int64>

# %%
friend15 = df1['friends'] >15

# %%
df1 [friend15]
# Out:
#      grade  weight  friends  cousins  projects
# 1       87      50       19        5        32
# 3       11      61       16        5        38
# 5       11      50       16        9        75
# 7       80      51       20        6        58
# 10      30      69       18        9        37
# ..     ...     ...      ...      ...       ...
# 993     47      53       19        7        50
# 994     75      57       16        9        42
# 996     44      69       19        7        64
# 997     82      66       18        8        30
# 999     28      54       20       10        49
#
# [434 rows x 5 columns]

# %%
grade50 = df1['grade'] >15

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 0       50      69       12       10        71
# 1       87      50       19        5        32
# 2       98      60       13        7        80
# 4       84      57       14        6        65
# 6       80      69       13        6        45
# ..     ...     ...      ...      ...       ...
# 994     75      57       16        9        42
# 995     50      70       13       10        70
# 996     44      69       19        7        64
# 997     82      66       18        8        30
# 999     28      54       20       10        49
#
# [867 rows x 5 columns]

# %%
df1[friend15 & grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 1       87      50       19        5        32
# 7       80      51       20        6        58
# 10      30      69       18        9        37
# 11      89      50       19        6        50
# 14      79      65       17        8        66
# ..     ...     ...      ...      ...       ...
# 993     47      53       19        7        50
# 994     75      57       16        9        42
# 996     44      69       19        7        64
# 997     82      66       18        8        30
# 999     28      54       20       10        49
#
# [368 rows x 5 columns]

# %%
 df1[friend15 & grade50]['friends'].value_counts()
# Out:
# friends
# 19    82
# 16    79
# 20    77
# 17    69
# 18    61
# Name: count, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
df1[friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
df1[friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
df1[friend15 & garde50].plot(x= 'grade',y = 'projects')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & garde50].plot(x= 'grade',y = 'projects',kind ='area')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & garde50].plot(x= 'grade',y = 'projects',kind='box')
# Out:
# <Axes: >

# %%
df1[friend15 & garde50].plot(x= 'grade',y = 'projects',kind ='pie')
# Out:
# <Axes: ylabel='projects'>

# %%
from matplotlib import pyplot as plt

# %%
df1[friend15 & garde50].plot(x= ['grade','friends'],y =['projects','weight'],kind ='scatter', title= 'sample graph')
plt.xlabel('x axis'),
plt.ylabel('y axis'),
plt.legend('test Data'),
plt.show()

# %%
df1.to_csv('/feb6testdata.csv')
